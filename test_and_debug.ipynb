# %%
import warnings
import os, sys, platform
import glob
from astropy.units import UnitsWarning
from pathlib import Path

# Ignorar warnings comunes de librerías externas
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UnitsWarning)
print("🔇 Warnings silenciados: UserWarning, FutureWarning")
# Desactivar Rich para evitar problemas de compatibilidad
os.environ["RICH_NO_RICH"] = "1"

# Asegurar que el directorio 'src' esté en el path de Python
src_path = Path("src").resolve()
if src_path not in sys.path:
    sys.path.append(str(src_path))
from src.script_1_eb import main as run_script_1

# Detectar entorno local/AWS y ejecutar el script
try:
    import sagemaker
    is_sagemaker = True
except ImportError:
    is_sagemaker = False

#existing = len(glob.glob("/home/ec2-user/backup/data/raw/kepler/*.csv")) + len(glob.glob("/home/ec2-user/backup/data/raw/tess/*.csv"))
existing = len(glob.glob("/home/ec2-user/backup/data/raw/tess/*.csv"))
print(f"🗃️ Curvas ya existentes en disco: {existing}", flush=True)

# Ejecutar con la opción adecuada
if is_sagemaker:
    print("🔁 Ejecutando en SageMaker → catálogo completo")
    # Solo TESS, solo pendientes
    run_script_1(mission="TESS", only_pending=True, max_workers=12)
else:
    print("💻 Ejecutando en entorno local → catálogo de prueba")
    run_script_1(use_sample=True)
# Out:
# 🔇 Warnings silenciados: UserWarning, FutureWarning
# 📁 Usando RAW_DIR: /home/ec2-user/backup/data/raw
# [05/16/25 12:52:48] INFO     Found credentials from IAM Role:                                   ]8;id=186713;file:///home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=859809;file:///home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# 🗃️ Curvas ya existentes en disco: 0
# 🔁 Ejecutando en SageMaker → catálogo completo
# [⬇] Descargando catálogos completos de Kepler y TESS...
# [⬇] Descargando catálogo Kepler EB...
# [📂] Cargando catálogo Kepler EB desde copia local...
# [⬇] Descargando catálogo TESS EB...
# [⬇] Generando CSV de entrada para descarga de curvas...
# 📝 CSV generado con 0 estrellas → data/lists/eb_ids.csv
# [⬇] Descargando curvas de luz...
#
# 🚀 Procesando misión: TESS (only_pending=True)
# 📝 CSV generado con 0 estrellas → data/lists/eb_ids_tess_pendientes.csv
# [⬇] Descargando 0 curvas en paralelo con 12 hilos...
# 🚀 Descargando curvas: 0it [00:00, ?it/s]
# 	📦 0 objetos procesados hasta ahora...
# [✓] Descarga finalizada: 0 objetos procesados.
# [⭢] Leyendo y fusionando curvas descargadas...
# [📁] Usando 16 lotes ya existentes en /home/ec2-user/temp_batches
# [⏳] Uniendo todos los lotes en /home/ec2-user/backup/processed/dataset_eb_tess.parquet...
# 📚 Uniendo lotes: 100%|██████████| 16/16 [03:14<00:00, 12.13s/it]
# [✅] Dataset parquet construido → /home/ec2-user/backup/processed/dataset_eb_tess.parquet
# 🧹 Carpeta temporal eliminada: /home/ec2-user/temp_batches
# [⏱] Tiempo total: 196.25 segundos

# %% [markdown]
# ### BACKUPS ANTES DE APAGAR INSTANCIA

# %%
import shutil, os
from pathlib import Path

# Crear carpeta de backup dentro de SageMaker
backup_dir = Path.home() / "SageMaker" / "backup"
backup_dir.mkdir(exist_ok=True)
print(f"📁 Carpeta de backup creada en: {backup_dir}")

# 🔁 NUEVO: Copiar curvas desde la nueva ubicación temporal
#raw_dir_kepler = Path("/home/ec2-user/backup/raw/kepler")
raw_dir_tess = Path("/home/ec2-user/backup/raw/tess")
if raw_dir.exists():
    #shutil.make_archive(backup_dir / "curvas_raw_kepler", "zip", raw_dir_kepler)
    #print("✅ Copiado: curvas en backup/raw/kepler → curvas_raw_kepler.zip")
    shutil.make_archive(backup_dir / "curvas_raw_tess", "zip", raw_dir_tess)
    print("✅ Copiado: curvas en backup/raw/tess → curvas_raw_tess.zip")
else:
    print("⚠️ No se encontró backup/raw")

# Copiar dataset procesado
processed_dir = Path("SageMaker/astro_transformer/data/processed")
if processed_dir.exists():
    for file in processed_dir.glob("*.parquet"):
        shutil.copy(file, backup_dir)
        print(f"✅ Copiado: {file.name}")
else:
    print("⚠️ No se encontró data/processed")

# Copiar log de errores si existe
error_log = Path("SageMaker/astro_transformer/logs/fallos_descarga.csv")
if error_log.exists():
    shutil.copy(error_log, backup_dir)
    print("✅ Copiado: logs/fallos_descarga.csv")

# Copiar caché de lightkurve si existe
lk_cache = Path.home() / ".lightkurve" / "cache"
if lk_cache.exists():
    shutil.make_archive(backup_dir / "lightkurve_cache", "zip", lk_cache)
    print("✅ Copiado: ~/.lightkurve/cache → lightkurve_cache.zip")

print("🎉 Backup completado.")

# %%
# Borrar cache de lightcurve
# !rm -rf ~/.lightkurve/cache/*

# %%
# %run src/script_5a_normalize_ids.py --mision vsx_tess
# Out:
# 🔧 Procesando VSX_TESS → dataset_vsx_tess_labeled.parquet
# 📝 Procesando batch #1...
# ✅ Batch #1 guardado en dataset_vsx_tess_labeled_batch_0000.parquet (131072 filas)
# 📝 Procesando batch #2...
# ✅ Batch #2 guardado en dataset_vsx_tess_labeled_batch_0001.parquet (131072 filas)
# 📝 Procesando batch #3...
# ✅ Batch #3 guardado en dataset_vsx_tess_labeled_batch_0002.parquet (131072 filas)
# 📝 Procesando batch #4...
# ✅ Batch #4 guardado en dataset_vsx_tess_labeled_batch_0003.parquet (131072 filas)
# 📝 Procesando batch #5...
# ✅ Batch #5 guardado en dataset_vsx_tess_labeled_batch_0004.parquet (131072 filas)
# 📝 Procesando batch #6...
# ✅ Batch #6 guardado en dataset_vsx_tess_labeled_batch_0005.parquet (131072 filas)
# 📝 Procesando batch #7...
# ✅ Batch #7 guardado en dataset_vsx_tess_labeled_batch_0006.parquet (131072 filas)
# 📝 Procesando batch #8...
# ✅ Batch #8 guardado en dataset_vsx_tess_labeled_batch_0007.parquet (131072 filas)
# 📝 Procesando batch #9...
# ✅ Batch #9 guardado en dataset_vsx_tess_labeled_batch_0008.parquet (131072 filas)
# 📝 Procesando batch #10...
# ✅ Batch #10 guardado en dataset_vsx_tess_labeled_batch_0009.parquet (131072 filas)
# 📝 Procesando batch #11...
# ✅ Batch #11 guardado en dataset_vsx_tess_labeled_batch_0010.parquet (131072 filas)
# 📝 Procesando batch #12...
# ✅ Batch #12 guardado en dataset_vsx_tess_labeled_batch_0011.parquet (131072 filas)
# 📝 Procesando batch #13...
# ✅ Batch #13 guardado en dataset_vsx_tess_labeled_batch_0012.parquet (131072 filas)
# 📝 Procesando batch #14...
# ✅ Batch #14 guardado en dataset_vsx_tess_labeled_batch_0013.parquet (131072 filas)
# 📝 Procesando batch #15...
# ✅ Batch #15 guardado en dataset_vsx_tess_labeled_batch_0014.parquet (131072 filas)
# 📝 Procesando batch #16...
# ✅ Batch #16 guardado en dataset_vsx_tess_labeled_batch_0015.parquet (131072 filas)
# 📝 Procesando batch #17...
# ✅ Batch #17 guardado en dataset_vsx_tess_labeled_batch_0016.parquet (131072 filas)
# 📝 Procesando batch #18...
# ✅ Batch #18 guardado en dataset_vsx_tess_labeled_batch_0017.parquet (131072 filas)
# 📝 Procesando batch #19...
# ✅ Batch #19 guardado en dataset_vsx_tess_labeled_batch_0018.parquet (131072 filas)
# 📝 Procesando batch #20...
# ✅ Batch #20 guardado en dataset_vsx_tess_labeled_batch_0019.parquet (131072 filas)
# 📝 Procesando batch #21...
# ✅ Batch #21 guardado en dataset_vsx_tess_labeled_batch_0020.parquet (131072 filas)
# 📝 Procesando batch #22...
# ✅ Batch #22 guardado en dataset_vsx_tess_labeled_batch_0021.parquet (131072 filas)
# 📝 Procesando batch #23...
# ✅ Batch #23 guardado en dataset_vsx_tess_labeled_batch_0022.parquet (131072 filas)
# 📝 Procesando batch #24...
# ✅ Batch #24 guardado en dataset_vsx_tess_labeled_batch_0023.parquet (131072 filas)
# 📝 Procesando batch #25...
# ✅ Batch #25 guardado en dataset_vsx_tess_labeled_batch_0024.parquet (131072 filas)
# 📝 Procesando batch #26...
# ✅ Batch #26 guardado en dataset_vsx_tess_labeled_batch_0025.parquet (131072 filas)
# 📝 Procesando batch #27...
# ✅ Batch #27 guardado en dataset_vsx_tess_labeled_batch_0026.parquet (131072 filas)
# 📝 Procesando batch #28...
# ✅ Batch #28 guardado en dataset_vsx_tess_labeled_batch_0027.parquet (131072 filas)
# 📝 Procesando batch #29...
# ✅ Batch #29 guardado en dataset_vsx_tess_labeled_batch_0028.parquet (131072 filas)
# 📝 Procesando batch #30...
# ✅ Batch #30 guardado en dataset_vsx_tess_labeled_batch_0029.parquet (131072 filas)
# 📝 Procesando batch #31...
# ✅ Batch #31 guardado en dataset_vsx_tess_labeled_batch_0030.parquet (131072 filas)
# 📝 Procesando batch #32...
# ✅ Batch #32 guardado en dataset_vsx_tess_labeled_batch_0031.parquet (131072 filas)
# 📝 Procesando batch #33...
# ✅ Batch #33 guardado en dataset_vsx_tess_labeled_batch_0032.parquet (131072 filas)
# 📝 Procesando batch #34...
# ✅ Batch #34 guardado en dataset_vsx_tess_labeled_batch_0033.parquet (131072 filas)
# 📝 Procesando batch #35...
# ✅ Batch #35 guardado en dataset_vsx_tess_labeled_batch_0034.parquet (131072 filas)
# 📝 Procesando batch #36...
# ✅ Batch #36 guardado en dataset_vsx_tess_labeled_batch_0035.parquet (131072 filas)
# 📝 Procesando batch #37...
# ✅ Batch #37 guardado en dataset_vsx_tess_labeled_batch_0036.parquet (131072 filas)
# 📝 Procesando batch #38...
# ✅ Batch #38 guardado en dataset_vsx_tess_labeled_batch_0037.parquet (131072 filas)
# 📝 Procesando batch #39...
# ✅ Batch #39 guardado en dataset_vsx_tess_labeled_batch_0038.parquet (131072 filas)
# 📝 Procesando batch #40...
# ✅ Batch #40 guardado en dataset_vsx_tess_labeled_batch_0039.parquet (131072 filas)
# 📝 Procesando batch #41...
# ✅ Batch #41 guardado en dataset_vsx_tess_labeled_batch_0040.parquet (131072 filas)
# 📝 Procesando batch #42...
# ✅ Batch #42 guardado en dataset_vsx_tess_labeled_batch_0041.parquet (131072 filas)
# 📝 Procesando batch #43...
# ✅ Batch #43 guardado en dataset_vsx_tess_labeled_batch_0042.parquet (131072 filas)
# 📝 Procesando batch #44...
# ✅ Batch #44 guardado en dataset_vsx_tess_labeled_batch_0043.parquet (131072 filas)
# 📝 Procesando batch #45...
# ✅ Batch #45 guardado en dataset_vsx_tess_labeled_batch_0044.parquet (131072 filas)
# 📝 Procesando batch #46...
# ✅ Batch #46 guardado en dataset_vsx_tess_labeled_batch_0045.parquet (131072 filas)
# 📝 Procesando batch #47...
# ✅ Batch #47 guardado en dataset_vsx_tess_labeled_batch_0046.parquet (131072 filas)
# 📝 Procesando batch #48...
# ✅ Batch #48 guardado en dataset_vsx_tess_labeled_batch_0047.parquet (131072 filas)
# 📝 Procesando batch #49...
# ✅ Batch #49 guardado en dataset_vsx_tess_labeled_batch_0048.parquet (131072 filas)
# 📝 Procesando batch #50...
# ✅ Batch #50 guardado en dataset_vsx_tess_labeled_batch_0049.parquet (131072 filas)
# 📝 Procesando batch #51...
# ✅ Batch #51 guardado en dataset_vsx_tess_labeled_batch_0050.parquet (131072 filas)
# 📝 Procesando batch #52...
# ✅ Batch #52 guardado en dataset_vsx_tess_labeled_batch_0051.parquet (131072 filas)
# 📝 Procesando batch #53...
# ✅ Batch #53 guardado en dataset_vsx_tess_labeled_batch_0052.parquet (131072 filas)
# 📝 Procesando batch #54...
# ✅ Batch #54 guardado en dataset_vsx_tess_labeled_batch_0053.parquet (131072 filas)
# 📝 Procesando batch #55...
# ✅ Batch #55 guardado en dataset_vsx_tess_labeled_batch_0054.parquet (131072 filas)
# 📝 Procesando batch #56...
# ✅ Batch #56 guardado en dataset_vsx_tess_labeled_batch_0055.parquet (131072 filas)
# 📝 Procesando batch #57...
# ✅ Batch #57 guardado en dataset_vsx_tess_labeled_batch_0056.parquet (131072 filas)
# 📝 Procesando batch #58...
# ✅ Batch #58 guardado en dataset_vsx_tess_labeled_batch_0057.parquet (131072 filas)
# 📝 Procesando batch #59...
# ✅ Batch #59 guardado en dataset_vsx_tess_labeled_batch_0058.parquet (131072 filas)
# 📝 Procesando batch #60...
# ✅ Batch #60 guardado en dataset_vsx_tess_labeled_batch_0059.parquet (131072 filas)
# 📝 Procesando batch #61...
# ✅ Batch #61 guardado en dataset_vsx_tess_labeled_batch_0060.parquet (131072 filas)
# 📝 Procesando batch #62...
# ✅ Batch #62 guardado en dataset_vsx_tess_labeled_batch_0061.parquet (131072 filas)
# 📝 Procesando batch #63...
# ✅ Batch #63 guardado en dataset_vsx_tess_labeled_batch_0062.parquet (131072 filas)
# 📝 Procesando batch #64...
# ✅ Batch #64 guardado en dataset_vsx_tess_labeled_batch_0063.parquet (131072 filas)
# 📝 Procesando batch #65...
# ✅ Batch #65 guardado en dataset_vsx_tess_labeled_batch_0064.parquet (131072 filas)
# 📝 Procesando batch #66...
# ✅ Batch #66 guardado en dataset_vsx_tess_labeled_batch_0065.parquet (131072 filas)
# 📝 Procesando batch #67...
# ✅ Batch #67 guardado en dataset_vsx_tess_labeled_batch_0066.parquet (131072 filas)
# 📝 Procesando batch #68...
# ✅ Batch #68 guardado en dataset_vsx_tess_labeled_batch_0067.parquet (131072 filas)
# 📝 Procesando batch #69...
# ✅ Batch #69 guardado en dataset_vsx_tess_labeled_batch_0068.parquet (131072 filas)
# 📝 Procesando batch #70...
# ✅ Batch #70 guardado en dataset_vsx_tess_labeled_batch_0069.parquet (131072 filas)
# 📝 Procesando batch #71...
# ✅ Batch #71 guardado en dataset_vsx_tess_labeled_batch_0070.parquet (131072 filas)
# 📝 Procesando batch #72...
# ✅ Batch #72 guardado en dataset_vsx_tess_labeled_batch_0071.parquet (131072 filas)
# 📝 Procesando batch #73...
# ✅ Batch #73 guardado en dataset_vsx_tess_labeled_batch_0072.parquet (131072 filas)
# 📝 Procesando batch #74...
# ✅ Batch #74 guardado en dataset_vsx_tess_labeled_batch_0073.parquet (131072 filas)
# 📝 Procesando batch #75...
# ✅ Batch #75 guardado en dataset_vsx_tess_labeled_batch_0074.parquet (131072 filas)
# 📝 Procesando batch #76...
# ✅ Batch #76 guardado en dataset_vsx_tess_labeled_batch_0075.parquet (131072 filas)
# 📝 Procesando batch #77...
# ✅ Batch #77 guardado en dataset_vsx_tess_labeled_batch_0076.parquet (131072 filas)
# 📝 Procesando batch #78...
# ✅ Batch #78 guardado en dataset_vsx_tess_labeled_batch_0077.parquet (131072 filas)
# 📝 Procesando batch #79...
# ✅ Batch #79 guardado en dataset_vsx_tess_labeled_batch_0078.parquet (131072 filas)
# 📝 Procesando batch #80...
# ✅ Batch #80 guardado en dataset_vsx_tess_labeled_batch_0079.parquet (131072 filas)
# 📝 Procesando batch #81...
# ✅ Batch #81 guardado en dataset_vsx_tess_labeled_batch_0080.parquet (131072 filas)
# 📝 Procesando batch #82...
# ✅ Batch #82 guardado en dataset_vsx_tess_labeled_batch_0081.parquet (131072 filas)
# 📝 Procesando batch #83...
# ✅ Batch #83 guardado en dataset_vsx_tess_labeled_batch_0082.parquet (131072 filas)
# 📝 Procesando batch #84...
# ✅ Batch #84 guardado en dataset_vsx_tess_labeled_batch_0083.parquet (131072 filas)
# 📝 Procesando batch #85...
# ✅ Batch #85 guardado en dataset_vsx_tess_labeled_batch_0084.parquet (131072 filas)
# 📝 Procesando batch #86...
# ✅ Batch #86 guardado en dataset_vsx_tess_labeled_batch_0085.parquet (131072 filas)
# 📝 Procesando batch #87...
# ✅ Batch #87 guardado en dataset_vsx_tess_labeled_batch_0086.parquet (131072 filas)
# 📝 Procesando batch #88...
# ✅ Batch #88 guardado en dataset_vsx_tess_labeled_batch_0087.parquet (131072 filas)
# 📝 Procesando batch #89...
# ✅ Batch #89 guardado en dataset_vsx_tess_labeled_batch_0088.parquet (131072 filas)
# 📝 Procesando batch #90...
# ✅ Batch #90 guardado en dataset_vsx_tess_labeled_batch_0089.parquet (131072 filas)
# 📝 Procesando batch #91...
# ✅ Batch #91 guardado en dataset_vsx_tess_labeled_batch_0090.parquet (131072 filas)
# 📝 Procesando batch #92...
# ✅ Batch #92 guardado en dataset_vsx_tess_labeled_batch_0091.parquet (131072 filas)
# 📝 Procesando batch #93...
# ✅ Batch #93 guardado en dataset_vsx_tess_labeled_batch_0092.parquet (131072 filas)
# 📝 Procesando batch #94...
# ✅ Batch #94 guardado en dataset_vsx_tess_labeled_batch_0093.parquet (131072 filas)
# 📝 Procesando batch #95...
# ✅ Batch #95 guardado en dataset_vsx_tess_labeled_batch_0094.parquet (131072 filas)
# 📝 Procesando batch #96...
# ✅ Batch #96 guardado en dataset_vsx_tess_labeled_batch_0095.parquet (131072 filas)
# 📝 Procesando batch #97...
# ✅ Batch #97 guardado en dataset_vsx_tess_labeled_batch_0096.parquet (131072 filas)
# 📝 Procesando batch #98...
# ✅ Batch #98 guardado en dataset_vsx_tess_labeled_batch_0097.parquet (131072 filas)
# 📝 Procesando batch #99...
# ✅ Batch #99 guardado en dataset_vsx_tess_labeled_batch_0098.parquet (131072 filas)
# 📝 Procesando batch #100...
# ✅ Batch #100 guardado en dataset_vsx_tess_labeled_batch_0099.parquet (131072 filas)
# 📝 Procesando batch #101...
# ✅ Batch #101 guardado en dataset_vsx_tess_labeled_batch_0100.parquet (131072 filas)
# 📝 Procesando batch #102...
# ✅ Batch #102 guardado en dataset_vsx_tess_labeled_batch_0101.parquet (131072 filas)
# 📝 Procesando batch #103...
# ✅ Batch #103 guardado en dataset_vsx_tess_labeled_batch_0102.parquet (131072 filas)
# 📝 Procesando batch #104...
# ✅ Batch #104 guardado en dataset_vsx_tess_labeled_batch_0103.parquet (131072 filas)
# 📝 Procesando batch #105...
# ✅ Batch #105 guardado en dataset_vsx_tess_labeled_batch_0104.parquet (131072 filas)
# 📝 Procesando batch #106...
# ✅ Batch #106 guardado en dataset_vsx_tess_labeled_batch_0105.parquet (131072 filas)
# 📝 Procesando batch #107...
# ✅ Batch #107 guardado en dataset_vsx_tess_labeled_batch_0106.parquet (131072 filas)
# 📝 Procesando batch #108...
# ✅ Batch #108 guardado en dataset_vsx_tess_labeled_batch_0107.parquet (131072 filas)
# 📝 Procesando batch #109...
# ✅ Batch #109 guardado en dataset_vsx_tess_labeled_batch_0108.parquet (131072 filas)
# 📝 Procesando batch #110...
# ✅ Batch #110 guardado en dataset_vsx_tess_labeled_batch_0109.parquet (131072 filas)
# 📝 Procesando batch #111...
# ✅ Batch #111 guardado en dataset_vsx_tess_labeled_batch_0110.parquet (131072 filas)
# 📝 Procesando batch #112...
# ✅ Batch #112 guardado en dataset_vsx_tess_labeled_batch_0111.parquet (131072 filas)
# 📝 Procesando batch #113...
# ✅ Batch #113 guardado en dataset_vsx_tess_labeled_batch_0112.parquet (131072 filas)
# 📝 Procesando batch #114...
# ✅ Batch #114 guardado en dataset_vsx_tess_labeled_batch_0113.parquet (131072 filas)
# 📝 Procesando batch #115...
# ✅ Batch #115 guardado en dataset_vsx_tess_labeled_batch_0114.parquet (131072 filas)
# 📝 Procesando batch #116...
# ✅ Batch #116 guardado en dataset_vsx_tess_labeled_batch_0115.parquet (131072 filas)
# 📝 Procesando batch #117...
# ✅ Batch #117 guardado en dataset_vsx_tess_labeled_batch_0116.parquet (131072 filas)
# 📝 Procesando batch #118...
# ✅ Batch #118 guardado en dataset_vsx_tess_labeled_batch_0117.parquet (131072 filas)
# 📝 Procesando batch #119...
# ✅ Batch #119 guardado en dataset_vsx_tess_labeled_batch_0118.parquet (131072 filas)
# 📝 Procesando batch #120...
# ✅ Batch #120 guardado en dataset_vsx_tess_labeled_batch_0119.parquet (131072 filas)
# 📝 Procesando batch #121...
# ✅ Batch #121 guardado en dataset_vsx_tess_labeled_batch_0120.parquet (131072 filas)
# 📝 Procesando batch #122...
# ✅ Batch #122 guardado en dataset_vsx_tess_labeled_batch_0121.parquet (131072 filas)
# 📝 Procesando batch #123...
# ✅ Batch #123 guardado en dataset_vsx_tess_labeled_batch_0122.parquet (131072 filas)
# 📝 Procesando batch #124...
# ✅ Batch #124 guardado en dataset_vsx_tess_labeled_batch_0123.parquet (131072 filas)
# 📝 Procesando batch #125...
# ✅ Batch #125 guardado en dataset_vsx_tess_labeled_batch_0124.parquet (131072 filas)
# 📝 Procesando batch #126...
# ✅ Batch #126 guardado en dataset_vsx_tess_labeled_batch_0125.parquet (131072 filas)
# 📝 Procesando batch #127...
# ✅ Batch #127 guardado en dataset_vsx_tess_labeled_batch_0126.parquet (131072 filas)
# 📝 Procesando batch #128...
# ✅ Batch #128 guardado en dataset_vsx_tess_labeled_batch_0127.parquet (131072 filas)
# 📝 Procesando batch #129...
# ✅ Batch #129 guardado en dataset_vsx_tess_labeled_batch_0128.parquet (131072 filas)
# 📝 Procesando batch #130...
# ✅ Batch #130 guardado en dataset_vsx_tess_labeled_batch_0129.parquet (131072 filas)
# 📝 Procesando batch #131...
# ✅ Batch #131 guardado en dataset_vsx_tess_labeled_batch_0130.parquet (131072 filas)
# 📝 Procesando batch #132...
# ✅ Batch #132 guardado en dataset_vsx_tess_labeled_batch_0131.parquet (131072 filas)
# 📝 Procesando batch #133...
# ✅ Batch #133 guardado en dataset_vsx_tess_labeled_batch_0132.parquet (131072 filas)
# 📝 Procesando batch #134...
# ✅ Batch #134 guardado en dataset_vsx_tess_labeled_batch_0133.parquet (131072 filas)
# 📝 Procesando batch #135...
# ✅ Batch #135 guardado en dataset_vsx_tess_labeled_batch_0134.parquet (131072 filas)
# 📝 Procesando batch #136...
# ✅ Batch #136 guardado en dataset_vsx_tess_labeled_batch_0135.parquet (131072 filas)
# 📝 Procesando batch #137...
# ✅ Batch #137 guardado en dataset_vsx_tess_labeled_batch_0136.parquet (131072 filas)
# 📝 Procesando batch #138...
# ✅ Batch #138 guardado en dataset_vsx_tess_labeled_batch_0137.parquet (131072 filas)
# 📝 Procesando batch #139...
# ✅ Batch #139 guardado en dataset_vsx_tess_labeled_batch_0138.parquet (131072 filas)
# 📝 Procesando batch #140...
# ✅ Batch #140 guardado en dataset_vsx_tess_labeled_batch_0139.parquet (131072 filas)
# 📝 Procesando batch #141...
# ✅ Batch #141 guardado en dataset_vsx_tess_labeled_batch_0140.parquet (131072 filas)
# 📝 Procesando batch #142...
# ✅ Batch #142 guardado en dataset_vsx_tess_labeled_batch_0141.parquet (131072 filas)
# 📝 Procesando batch #143...
# ✅ Batch #143 guardado en dataset_vsx_tess_labeled_batch_0142.parquet (131072 filas)
# 📝 Procesando batch #144...
# ✅ Batch #144 guardado en dataset_vsx_tess_labeled_batch_0143.parquet (131072 filas)
# 📝 Procesando batch #145...
# ✅ Batch #145 guardado en dataset_vsx_tess_labeled_batch_0144.parquet (131072 filas)
# 📝 Procesando batch #146...
# ✅ Batch #146 guardado en dataset_vsx_tess_labeled_batch_0145.parquet (131072 filas)
# 📝 Procesando batch #147...
# ✅ Batch #147 guardado en dataset_vsx_tess_labeled_batch_0146.parquet (131072 filas)
# 📝 Procesando batch #148...
# ✅ Batch #148 guardado en dataset_vsx_tess_labeled_batch_0147.parquet (131072 filas)
# 📝 Procesando batch #149...
# ✅ Batch #149 guardado en dataset_vsx_tess_labeled_batch_0148.parquet (131072 filas)
# 📝 Procesando batch #150...
# ✅ Batch #150 guardado en dataset_vsx_tess_labeled_batch_0149.parquet (131072 filas)
# 📝 Procesando batch #151...
# ✅ Batch #151 guardado en dataset_vsx_tess_labeled_batch_0150.parquet (131072 filas)
# 📝 Procesando batch #152...
# ✅ Batch #152 guardado en dataset_vsx_tess_labeled_batch_0151.parquet (131072 filas)
# 📝 Procesando batch #153...
# ✅ Batch #153 guardado en dataset_vsx_tess_labeled_batch_0152.parquet (131072 filas)
# 📝 Procesando batch #154...
# ✅ Batch #154 guardado en dataset_vsx_tess_labeled_batch_0153.parquet (131072 filas)
# 📝 Procesando batch #155...
# ✅ Batch #155 guardado en dataset_vsx_tess_labeled_batch_0154.parquet (131072 filas)
# 📝 Procesando batch #156...
# ✅ Batch #156 guardado en dataset_vsx_tess_labeled_batch_0155.parquet (131072 filas)
# 📝 Procesando batch #157...
# ✅ Batch #157 guardado en dataset_vsx_tess_labeled_batch_0156.parquet (131072 filas)
# 📝 Procesando batch #158...
# ✅ Batch #158 guardado en dataset_vsx_tess_labeled_batch_0157.parquet (131072 filas)
# 📝 Procesando batch #159...
# ✅ Batch #159 guardado en dataset_vsx_tess_labeled_batch_0158.parquet (131072 filas)
# 📝 Procesando batch #160...
# ✅ Batch #160 guardado en dataset_vsx_tess_labeled_batch_0159.parquet (131072 filas)
# 📝 Procesando batch #161...
# ✅ Batch #161 guardado en dataset_vsx_tess_labeled_batch_0160.parquet (131072 filas)
# 📝 Procesando batch #162...
# ✅ Batch #162 guardado en dataset_vsx_tess_labeled_batch_0161.parquet (131072 filas)
# 📝 Procesando batch #163...
# ✅ Batch #163 guardado en dataset_vsx_tess_labeled_batch_0162.parquet (131072 filas)
# 📝 Procesando batch #164...
# ✅ Batch #164 guardado en dataset_vsx_tess_labeled_batch_0163.parquet (131072 filas)
# 📝 Procesando batch #165...
# ✅ Batch #165 guardado en dataset_vsx_tess_labeled_batch_0164.parquet (131072 filas)
# 📝 Procesando batch #166...
# ✅ Batch #166 guardado en dataset_vsx_tess_labeled_batch_0165.parquet (131072 filas)
# 📝 Procesando batch #167...
# ✅ Batch #167 guardado en dataset_vsx_tess_labeled_batch_0166.parquet (131072 filas)
# 📝 Procesando batch #168...
# ✅ Batch #168 guardado en dataset_vsx_tess_labeled_batch_0167.parquet (131072 filas)
# 📝 Procesando batch #169...
# ✅ Batch #169 guardado en dataset_vsx_tess_labeled_batch_0168.parquet (131072 filas)
# 📝 Procesando batch #170...
# ✅ Batch #170 guardado en dataset_vsx_tess_labeled_batch_0169.parquet (131072 filas)
# 📝 Procesando batch #171...
# ✅ Batch #171 guardado en dataset_vsx_tess_labeled_batch_0170.parquet (131072 filas)
# 📝 Procesando batch #172...
# ✅ Batch #172 guardado en dataset_vsx_tess_labeled_batch_0171.parquet (131072 filas)
# 📝 Procesando batch #173...
# ✅ Batch #173 guardado en dataset_vsx_tess_labeled_batch_0172.parquet (131072 filas)
# 📝 Procesando batch #174...
# ✅ Batch #174 guardado en dataset_vsx_tess_labeled_batch_0173.parquet (131072 filas)
# 📝 Procesando batch #175...
# ✅ Batch #175 guardado en dataset_vsx_tess_labeled_batch_0174.parquet (131072 filas)
# 📝 Procesando batch #176...
# ✅ Batch #176 guardado en dataset_vsx_tess_labeled_batch_0175.parquet (131072 filas)
# 📝 Procesando batch #177...
# ✅ Batch #177 guardado en dataset_vsx_tess_labeled_batch_0176.parquet (131072 filas)
# 📝 Procesando batch #178...
# ✅ Batch #178 guardado en dataset_vsx_tess_labeled_batch_0177.parquet (131072 filas)
# 📝 Procesando batch #179...
# ✅ Batch #179 guardado en dataset_vsx_tess_labeled_batch_0178.parquet (131072 filas)
# 📝 Procesando batch #180...
# ✅ Batch #180 guardado en dataset_vsx_tess_labeled_batch_0179.parquet (131072 filas)
# 📝 Procesando batch #181...
# ✅ Batch #181 guardado en dataset_vsx_tess_labeled_batch_0180.parquet (131072 filas)
# 📝 Procesando batch #182...
# ✅ Batch #182 guardado en dataset_vsx_tess_labeled_batch_0181.parquet (131072 filas)
# 📝 Procesando batch #183...
# ✅ Batch #183 guardado en dataset_vsx_tess_labeled_batch_0182.parquet (131072 filas)
# 📝 Procesando batch #184...
# ✅ Batch #184 guardado en dataset_vsx_tess_labeled_batch_0183.parquet (131072 filas)
# 📝 Procesando batch #185...
# ✅ Batch #185 guardado en dataset_vsx_tess_labeled_batch_0184.parquet (131072 filas)
# 📝 Procesando batch #186...
# ✅ Batch #186 guardado en dataset_vsx_tess_labeled_batch_0185.parquet (131072 filas)
# 📝 Procesando batch #187...
# ✅ Batch #187 guardado en dataset_vsx_tess_labeled_batch_0186.parquet (131072 filas)
# 📝 Procesando batch #188...
# ✅ Batch #188 guardado en dataset_vsx_tess_labeled_batch_0187.parquet (131072 filas)
# 📝 Procesando batch #189...
# ✅ Batch #189 guardado en dataset_vsx_tess_labeled_batch_0188.parquet (131072 filas)
# 📝 Procesando batch #190...
# ✅ Batch #190 guardado en dataset_vsx_tess_labeled_batch_0189.parquet (131072 filas)
# 📝 Procesando batch #191...
# ✅ Batch #191 guardado en dataset_vsx_tess_labeled_batch_0190.parquet (131072 filas)
# 📝 Procesando batch #192...
# ✅ Batch #192 guardado en dataset_vsx_tess_labeled_batch_0191.parquet (131072 filas)
# 📝 Procesando batch #193...
# ✅ Batch #193 guardado en dataset_vsx_tess_labeled_batch_0192.parquet (131072 filas)
# 📝 Procesando batch #194...
# ✅ Batch #194 guardado en dataset_vsx_tess_labeled_batch_0193.parquet (131072 filas)
# 📝 Procesando batch #195...
# ✅ Batch #195 guardado en dataset_vsx_tess_labeled_batch_0194.parquet (131072 filas)
# 📝 Procesando batch #196...
# ✅ Batch #196 guardado en dataset_vsx_tess_labeled_batch_0195.parquet (131072 filas)
# 📝 Procesando batch #197...
# ✅ Batch #197 guardado en dataset_vsx_tess_labeled_batch_0196.parquet (131072 filas)
# 📝 Procesando batch #198...
# ✅ Batch #198 guardado en dataset_vsx_tess_labeled_batch_0197.parquet (131072 filas)
# 📝 Procesando batch #199...
# ✅ Batch #199 guardado en dataset_vsx_tess_labeled_batch_0198.parquet (131072 filas)
# 📝 Procesando batch #200...
# ✅ Batch #200 guardado en dataset_vsx_tess_labeled_batch_0199.parquet (131072 filas)
# 📝 Procesando batch #201...
# ✅ Batch #201 guardado en dataset_vsx_tess_labeled_batch_0200.parquet (131072 filas)
# 📝 Procesando batch #202...
# ✅ Batch #202 guardado en dataset_vsx_tess_labeled_batch_0201.parquet (131072 filas)
# 📝 Procesando batch #203...
# ✅ Batch #203 guardado en dataset_vsx_tess_labeled_batch_0202.parquet (131072 filas)
# 📝 Procesando batch #204...
# ✅ Batch #204 guardado en dataset_vsx_tess_labeled_batch_0203.parquet (131072 filas)
# 📝 Procesando batch #205...
# ✅ Batch #205 guardado en dataset_vsx_tess_labeled_batch_0204.parquet (131072 filas)
# 📝 Procesando batch #206...
# ✅ Batch #206 guardado en dataset_vsx_tess_labeled_batch_0205.parquet (131072 filas)
# 📝 Procesando batch #207...
# ✅ Batch #207 guardado en dataset_vsx_tess_labeled_batch_0206.parquet (131072 filas)
# 📝 Procesando batch #208...
# ✅ Batch #208 guardado en dataset_vsx_tess_labeled_batch_0207.parquet (131072 filas)
# 📝 Procesando batch #209...
# ✅ Batch #209 guardado en dataset_vsx_tess_labeled_batch_0208.parquet (131072 filas)
# 📝 Procesando batch #210...
# ✅ Batch #210 guardado en dataset_vsx_tess_labeled_batch_0209.parquet (131072 filas)
# 📝 Procesando batch #211...
# ✅ Batch #211 guardado en dataset_vsx_tess_labeled_batch_0210.parquet (131072 filas)
# 📝 Procesando batch #212...
# ✅ Batch #212 guardado en dataset_vsx_tess_labeled_batch_0211.parquet (131072 filas)
# 📝 Procesando batch #213...
# ✅ Batch #213 guardado en dataset_vsx_tess_labeled_batch_0212.parquet (131072 filas)
# 📝 Procesando batch #214...
# ✅ Batch #214 guardado en dataset_vsx_tess_labeled_batch_0213.parquet (131072 filas)
# 📝 Procesando batch #215...
# ✅ Batch #215 guardado en dataset_vsx_tess_labeled_batch_0214.parquet (131072 filas)
# 📝 Procesando batch #216...
# ✅ Batch #216 guardado en dataset_vsx_tess_labeled_batch_0215.parquet (131072 filas)
# 📝 Procesando batch #217...
# ✅ Batch #217 guardado en dataset_vsx_tess_labeled_batch_0216.parquet (131072 filas)
# 📝 Procesando batch #218...
# ✅ Batch #218 guardado en dataset_vsx_tess_labeled_batch_0217.parquet (131072 filas)
# 📝 Procesando batch #219...
# ✅ Batch #219 guardado en dataset_vsx_tess_labeled_batch_0218.parquet (131072 filas)
# 📝 Procesando batch #220...
# ✅ Batch #220 guardado en dataset_vsx_tess_labeled_batch_0219.parquet (131072 filas)
# 📝 Procesando batch #221...
# ✅ Batch #221 guardado en dataset_vsx_tess_labeled_batch_0220.parquet (131072 filas)
# 📝 Procesando batch #222...
# ✅ Batch #222 guardado en dataset_vsx_tess_labeled_batch_0221.parquet (131072 filas)
# 📝 Procesando batch #223...
# ✅ Batch #223 guardado en dataset_vsx_tess_labeled_batch_0222.parquet (131072 filas)
# 📝 Procesando batch #224...
# ✅ Batch #224 guardado en dataset_vsx_tess_labeled_batch_0223.parquet (131072 filas)
# 📝 Procesando batch #225...
# ✅ Batch #225 guardado en dataset_vsx_tess_labeled_batch_0224.parquet (131072 filas)
# 📝 Procesando batch #226...
# ✅ Batch #226 guardado en dataset_vsx_tess_labeled_batch_0225.parquet (131072 filas)
# 📝 Procesando batch #227...
# ✅ Batch #227 guardado en dataset_vsx_tess_labeled_batch_0226.parquet (131072 filas)
# 📝 Procesando batch #228...
# ✅ Batch #228 guardado en dataset_vsx_tess_labeled_batch_0227.parquet (131072 filas)
# 📝 Procesando batch #229...
# ✅ Batch #229 guardado en dataset_vsx_tess_labeled_batch_0228.parquet (131072 filas)
# 📝 Procesando batch #230...
# ✅ Batch #230 guardado en dataset_vsx_tess_labeled_batch_0229.parquet (131072 filas)
# 📝 Procesando batch #231...
# ✅ Batch #231 guardado en dataset_vsx_tess_labeled_batch_0230.parquet (131072 filas)
# 📝 Procesando batch #232...
# ✅ Batch #232 guardado en dataset_vsx_tess_labeled_batch_0231.parquet (131072 filas)
# 📝 Procesando batch #233...
# ✅ Batch #233 guardado en dataset_vsx_tess_labeled_batch_0232.parquet (131072 filas)
# 📝 Procesando batch #234...
# ✅ Batch #234 guardado en dataset_vsx_tess_labeled_batch_0233.parquet (131072 filas)
# 📝 Procesando batch #235...
# ✅ Batch #235 guardado en dataset_vsx_tess_labeled_batch_0234.parquet (131072 filas)
# 📝 Procesando batch #236...
# ✅ Batch #236 guardado en dataset_vsx_tess_labeled_batch_0235.parquet (131072 filas)
# 📝 Procesando batch #237...
# ✅ Batch #237 guardado en dataset_vsx_tess_labeled_batch_0236.parquet (131072 filas)
# 📝 Procesando batch #238...
# ✅ Batch #238 guardado en dataset_vsx_tess_labeled_batch_0237.parquet (131072 filas)
# 📝 Procesando batch #239...
# ✅ Batch #239 guardado en dataset_vsx_tess_labeled_batch_0238.parquet (131072 filas)
# 📝 Procesando batch #240...
# ✅ Batch #240 guardado en dataset_vsx_tess_labeled_batch_0239.parquet (131072 filas)
# 📝 Procesando batch #241...
# ✅ Batch #241 guardado en dataset_vsx_tess_labeled_batch_0240.parquet (131072 filas)
# 📝 Procesando batch #242...
# ✅ Batch #242 guardado en dataset_vsx_tess_labeled_batch_0241.parquet (131072 filas)
# 📝 Procesando batch #243...
# ✅ Batch #243 guardado en dataset_vsx_tess_labeled_batch_0242.parquet (131072 filas)
# 📝 Procesando batch #244...
# ✅ Batch #244 guardado en dataset_vsx_tess_labeled_batch_0243.parquet (131072 filas)
# 📝 Procesando batch #245...
# ✅ Batch #245 guardado en dataset_vsx_tess_labeled_batch_0244.parquet (131072 filas)
# 📝 Procesando batch #246...
# ✅ Batch #246 guardado en dataset_vsx_tess_labeled_batch_0245.parquet (131072 filas)
# 📝 Procesando batch #247...
# ✅ Batch #247 guardado en dataset_vsx_tess_labeled_batch_0246.parquet (131072 filas)
# 📝 Procesando batch #248...
# ✅ Batch #248 guardado en dataset_vsx_tess_labeled_batch_0247.parquet (131072 filas)
# 📝 Procesando batch #249...
# ✅ Batch #249 guardado en dataset_vsx_tess_labeled_batch_0248.parquet (131072 filas)
# 📝 Procesando batch #250...
# ✅ Batch #250 guardado en dataset_vsx_tess_labeled_batch_0249.parquet (131072 filas)
# 📝 Procesando batch #251...
# ✅ Batch #251 guardado en dataset_vsx_tess_labeled_batch_0250.parquet (131072 filas)
# 📝 Procesando batch #252...
# ✅ Batch #252 guardado en dataset_vsx_tess_labeled_batch_0251.parquet (131072 filas)
# 📝 Procesando batch #253...
# ✅ Batch #253 guardado en dataset_vsx_tess_labeled_batch_0252.parquet (131072 filas)
# 📝 Procesando batch #254...
# ✅ Batch #254 guardado en dataset_vsx_tess_labeled_batch_0253.parquet (131072 filas)
# 📝 Procesando batch #255...
# ✅ Batch #255 guardado en dataset_vsx_tess_labeled_batch_0254.parquet (131072 filas)
# 📝 Procesando batch #256...
# ✅ Batch #256 guardado en dataset_vsx_tess_labeled_batch_0255.parquet (131072 filas)
# 📝 Procesando batch #257...
# ✅ Batch #257 guardado en dataset_vsx_tess_labeled_batch_0256.parquet (131072 filas)
# 📝 Procesando batch #258...
# ✅ Batch #258 guardado en dataset_vsx_tess_labeled_batch_0257.parquet (131072 filas)
# 📝 Procesando batch #259...
# ✅ Batch #259 guardado en dataset_vsx_tess_labeled_batch_0258.parquet (131072 filas)
# 📝 Procesando batch #260...
# ✅ Batch #260 guardado en dataset_vsx_tess_labeled_batch_0259.parquet (131072 filas)
# 📝 Procesando batch #261...
# ✅ Batch #261 guardado en dataset_vsx_tess_labeled_batch_0260.parquet (131072 filas)
# 📝 Procesando batch #262...
# ✅ Batch #262 guardado en dataset_vsx_tess_labeled_batch_0261.parquet (131072 filas)
# 📝 Procesando batch #263...
# ✅ Batch #263 guardado en dataset_vsx_tess_labeled_batch_0262.parquet (131072 filas)
# 📝 Procesando batch #264...
# ✅ Batch #264 guardado en dataset_vsx_tess_labeled_batch_0263.parquet (131072 filas)
# 📝 Procesando batch #265...
# ✅ Batch #265 guardado en dataset_vsx_tess_labeled_batch_0264.parquet (131072 filas)
# 📝 Procesando batch #266...
# ✅ Batch #266 guardado en dataset_vsx_tess_labeled_batch_0265.parquet (131072 filas)
# 📝 Procesando batch #267...
# ✅ Batch #267 guardado en dataset_vsx_tess_labeled_batch_0266.parquet (131072 filas)
# 📝 Procesando batch #268...
# ✅ Batch #268 guardado en dataset_vsx_tess_labeled_batch_0267.parquet (131072 filas)
# 📝 Procesando batch #269...
# ✅ Batch #269 guardado en dataset_vsx_tess_labeled_batch_0268.parquet (131072 filas)
# 📝 Procesando batch #270...
# ✅ Batch #270 guardado en dataset_vsx_tess_labeled_batch_0269.parquet (131072 filas)
# 📝 Procesando batch #271...
# ✅ Batch #271 guardado en dataset_vsx_tess_labeled_batch_0270.parquet (131072 filas)
# 📝 Procesando batch #272...
# ✅ Batch #272 guardado en dataset_vsx_tess_labeled_batch_0271.parquet (131072 filas)
# 📝 Procesando batch #273...
# ✅ Batch #273 guardado en dataset_vsx_tess_labeled_batch_0272.parquet (131072 filas)
# 📝 Procesando batch #274...
# ✅ Batch #274 guardado en dataset_vsx_tess_labeled_batch_0273.parquet (131072 filas)
# 📝 Procesando batch #275...
# ✅ Batch #275 guardado en dataset_vsx_tess_labeled_batch_0274.parquet (131072 filas)
# 📝 Procesando batch #276...
# ✅ Batch #276 guardado en dataset_vsx_tess_labeled_batch_0275.parquet (131072 filas)
# 📝 Procesando batch #277...
# ✅ Batch #277 guardado en dataset_vsx_tess_labeled_batch_0276.parquet (131072 filas)
# 📝 Procesando batch #278...
# ✅ Batch #278 guardado en dataset_vsx_tess_labeled_batch_0277.parquet (131072 filas)
# 📝 Procesando batch #279...
# ✅ Batch #279 guardado en dataset_vsx_tess_labeled_batch_0278.parquet (131072 filas)
# 📝 Procesando batch #280...
# ✅ Batch #280 guardado en dataset_vsx_tess_labeled_batch_0279.parquet (131072 filas)
# 📝 Procesando batch #281...
# ✅ Batch #281 guardado en dataset_vsx_tess_labeled_batch_0280.parquet (131072 filas)
# 📝 Procesando batch #282...
# ✅ Batch #282 guardado en dataset_vsx_tess_labeled_batch_0281.parquet (131072 filas)
# 📝 Procesando batch #283...
# ✅ Batch #283 guardado en dataset_vsx_tess_labeled_batch_0282.parquet (131072 filas)
# 📝 Procesando batch #284...
# ✅ Batch #284 guardado en dataset_vsx_tess_labeled_batch_0283.parquet (131072 filas)
# 📝 Procesando batch #285...
# ✅ Batch #285 guardado en dataset_vsx_tess_labeled_batch_0284.parquet (131072 filas)
# 📝 Procesando batch #286...
# ✅ Batch #286 guardado en dataset_vsx_tess_labeled_batch_0285.parquet (131072 filas)
# 📝 Procesando batch #287...
# ✅ Batch #287 guardado en dataset_vsx_tess_labeled_batch_0286.parquet (131072 filas)
# 📝 Procesando batch #288...
# ✅ Batch #288 guardado en dataset_vsx_tess_labeled_batch_0287.parquet (131072 filas)
# 📝 Procesando batch #289...
# ✅ Batch #289 guardado en dataset_vsx_tess_labeled_batch_0288.parquet (131072 filas)
# 📝 Procesando batch #290...
# ✅ Batch #290 guardado en dataset_vsx_tess_labeled_batch_0289.parquet (131072 filas)
# 📝 Procesando batch #291...
# ✅ Batch #291 guardado en dataset_vsx_tess_labeled_batch_0290.parquet (131072 filas)
# 📝 Procesando batch #292...
# ✅ Batch #292 guardado en dataset_vsx_tess_labeled_batch_0291.parquet (131072 filas)
# 📝 Procesando batch #293...
# ✅ Batch #293 guardado en dataset_vsx_tess_labeled_batch_0292.parquet (131072 filas)
# 📝 Procesando batch #294...
# ✅ Batch #294 guardado en dataset_vsx_tess_labeled_batch_0293.parquet (131072 filas)
# 📝 Procesando batch #295...
# ✅ Batch #295 guardado en dataset_vsx_tess_labeled_batch_0294.parquet (131072 filas)
# 📝 Procesando batch #296...
# ✅ Batch #296 guardado en dataset_vsx_tess_labeled_batch_0295.parquet (131072 filas)
# 📝 Procesando batch #297...
# ✅ Batch #297 guardado en dataset_vsx_tess_labeled_batch_0296.parquet (131072 filas)
# 📝 Procesando batch #298...
# ✅ Batch #298 guardado en dataset_vsx_tess_labeled_batch_0297.parquet (131072 filas)
# 📝 Procesando batch #299...
# ✅ Batch #299 guardado en dataset_vsx_tess_labeled_batch_0298.parquet (131072 filas)
# 📝 Procesando batch #300...
# ✅ Batch #300 guardado en dataset_vsx_tess_labeled_batch_0299.parquet (131072 filas)
# 📝 Procesando batch #301...
# ✅ Batch #301 guardado en dataset_vsx_tess_labeled_batch_0300.parquet (131072 filas)
# 📝 Procesando batch #302...
# ✅ Batch #302 guardado en dataset_vsx_tess_labeled_batch_0301.parquet (131072 filas)
# 📝 Procesando batch #303...
# ✅ Batch #303 guardado en dataset_vsx_tess_labeled_batch_0302.parquet (131072 filas)
# 📝 Procesando batch #304...
# ✅ Batch #304 guardado en dataset_vsx_tess_labeled_batch_0303.parquet (131072 filas)
# 📝 Procesando batch #305...
# ✅ Batch #305 guardado en dataset_vsx_tess_labeled_batch_0304.parquet (131072 filas)
# 📝 Procesando batch #306...
# ✅ Batch #306 guardado en dataset_vsx_tess_labeled_batch_0305.parquet (131072 filas)
# 📝 Procesando batch #307...
# ✅ Batch #307 guardado en dataset_vsx_tess_labeled_batch_0306.parquet (131072 filas)
# 📝 Procesando batch #308...
# ✅ Batch #308 guardado en dataset_vsx_tess_labeled_batch_0307.parquet (131072 filas)
# 📝 Procesando batch #309...
# ✅ Batch #309 guardado en dataset_vsx_tess_labeled_batch_0308.parquet (131072 filas)
# 📝 Procesando batch #310...
# ✅ Batch #310 guardado en dataset_vsx_tess_labeled_batch_0309.parquet (131072 filas)
# 📝 Procesando batch #311...
# ✅ Batch #311 guardado en dataset_vsx_tess_labeled_batch_0310.parquet (131072 filas)
# 📝 Procesando batch #312...
# ✅ Batch #312 guardado en dataset_vsx_tess_labeled_batch_0311.parquet (131072 filas)
# 📝 Procesando batch #313...
# ✅ Batch #313 guardado en dataset_vsx_tess_labeled_batch_0312.parquet (131072 filas)
# 📝 Procesando batch #314...
# ✅ Batch #314 guardado en dataset_vsx_tess_labeled_batch_0313.parquet (118061 filas)
# 🔗 Unificando 314 batches en dataset_vsx_tess_labeled_fixed.parquet...
# ✅ Dataset unificado guardado como dataset_vsx_tess_labeled_fixed.parquet
# 🧹 Archivos temporales eliminados.

# %%
import pandas as pd
df = pd.read_parquet("data/processed/dataset_vsx_tic_labeled_north.parquet")
print(df.shape)
print(df["clase_variable"].value_counts())
# Out:
# (27999, 9)
# clase_variable
# ROT                14332
# EW                  2018
# RS                  2012
# DSCT|GDOR|SXPHE     1813
# E                   1658
#                    ...
# IN:                    1
# NL+E                   1
# Microlens              1
# CWA                    1
# EA/GS                  1
# Name: count, Length: 115, dtype: int64

# %%
from src.utils.inspect_and_export_summary import inspect_and_export_summary

OUTPUT_PARQUET_SOUTH = "data/processed/dataset_vsx_tess_labeled_south.parquet"
OUTPUT_PARQUET_NORTH = "data/processed/dataset_vsx_tess_labeled_north.parquet"

inspect_and_export_summary(OUTPUT_PARQUET_SOUTH, output_format="csv")
inspect_and_export_summary(OUTPUT_PARQUET_NORTH, output_format="csv")
# Out:
# 📁 Inspeccionando: data/processed/dataset_vsx_tess_labeled_south.parquet
# 🧮 Procesando por lotes: 24it [00:38,  1.60s/it]
# ✅ Resumen exportado a: data/processed/summary\dataset_vsx_tess_labeled_south_summary.csv
#
# 📁 Inspeccionando: data/processed/dataset_vsx_tess_labeled_north.parquet
# 🧮 Procesando por lotes: 434it [14:01,  1.94s/it]
# ✅ Resumen exportado a: data/processed/summary\dataset_vsx_tess_labeled_north_summary.csv
